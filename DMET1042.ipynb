# %%
# Current Weather Information Retrieval Program

import requests
import datetime
import time

API_KEY = '9ab9a8c1afe3b58d25474f99f0de76d2'
UPDATE_INTERVAL = 10  # Update every x seconds

def get_weather(city):
    base_url = f'https://api.openweathermap.org/data/2.5/weather'
    params = {'q': city, 'appid': API_KEY, 'units': 'metric'}
    response = requests.get(base_url, params=params)
    data = response.json()
    print(f"API Request URL: {response.url}")
    print(f"API Request Headers: {response.request.headers}")
    print(f"API Response Content: {response.content}")

    if response.status_code == 200:
        return data
    else:
        print(f"API response content: {response.content}")
        return None

def print_weather_data(data):
    print("  ")
    print(f"Weather in {data['name']}, {data['sys']['country']}:")
    print(f"Temperature: {data['main']['temp']}°C")
    print(f"Description: {data['weather'][0]['description']}")
    print(f"Humidity: {data['main']['humidity']}%")
    print(f"Pressure: {data['main']['pressure']} hPa")
    print(f"Wind Speed: {data['wind']['speed']} m/s")
    print(f"Wind Direction: {data['wind']['deg']}°")
    print(f"Cloudiness: {data['clouds']['all']}%")
    print(f"Visibility: {data['visibility'] / 1000} km")
    print(f"Sunrise: {datetime.datetime.utcfromtimestamp(data['sys']['sunrise']).strftime('%H:%M:%S')} UTC")
    print(f"Sunset: {datetime.datetime.utcfromtimestamp(data['sys']['sunset']).strftime('%H:%M:%S')} UTC")

def main():
    city = input("Enter city name: ")

    while True:
        weather_data = get_weather(city)

        if weather_data:
            print_weather_data(weather_data)
        else:
            print("Weather data not available.")

        print("=" * 30)  # Add a separator for clarity

        # Check if user wants to terminate
        terminate = input("Do you want to terminate? (yes/no): ")
        if terminate.lower() == "yes":
            print("=" * 30)  # Add a separator for clarity
            print("Terminating the session...")
            print("session Terminated ")
            break
        print("=" * 30)  # Add a separator for clarity

        time.sleep(UPDATE_INTERVAL)

if __name__ == "__main__":
    main()
# Out:
# Enter city name: cairo
# API Request URL: https://api.openweathermap.org/data/2.5/weather?q=cairo&appid=9ab9a8c1afe3b58d25474f99f0de76d2&units=metric
# API Request Headers: {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# API Response Content: b'{"coord":{"lon":31.2497,"lat":30.0626},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":26.42,"feels_like":26.42,"temp_min":25.79,"temp_max":26.42,"pressure":1014,"humidity":69},"visibility":10000,"wind":{"speed":4.63,"deg":30},"clouds":{"all":0},"dt":1693610669,"sys":{"type":1,"id":2514,"country":"EG","sunrise":1693625543,"sunset":1693671467},"timezone":10800,"id":360630,"name":"Cairo","cod":200}'
#
# Weather in Cairo, EG:
# Temperature: 26.42°C
# Description: clear sky
# Humidity: 69%
# Pressure: 1014 hPa
# Wind Speed: 4.63 m/s
# Wind Direction: 30°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: 03:32:23 UTC
# Sunset: 16:17:47 UTC
# ==============================
# Do you want to terminate? (yes/no): yes
# ==============================
# Terminating the session...
# session Terminated

# %%
# Weather Forecast Retrieval Program

import requests
import datetime
import time

API_KEY = '9ab9a8c1afe3b58d25474f99f0de76d2'
#UPDATE_INTERVAL = 10  # Update every x seconds

def get_weather(city, start_date, end_date):
    base_url = f'https://api.openweathermap.org/data/2.5/forecast'
    params = {'q': city, 'appid': API_KEY, 'units': 'metric',
             'start_date': start_date, 'end_date': end_date}
    response = requests.get(base_url, params=params)
    data = response.json()
    print(f"API Request URL: {response.url}")
    print(f"API Request Headers: {response.request.headers}")
    print(f"API Response Content: {response.content}")

    if response.status_code == 200:
        return data
    else:
        print(f"API response content: {response.content}")
        return None

def print_weather_data(data, units='metric'):
    print("  ")
    print(f"Weather in {data['city']['name']} from {start_date} to {end_date}:")
    for day in data['list']:
        temperature = day['main']
        temperature_dict = dict(temperature)
        temperature = temperature_dict.get('day', None)
        sunrise = None
        if sunrise in day['sys']:
            sunrise = datetime.datetime.utcfromtimestamp(day['sys']['sunrise']).strftime('%H:%M:%S')
        else:
            sunrise = None
        print(f"Date: {day['dt']}")
        print(f"Temperature: {temperature}°")
        print(f"Description: {day['weather'][0]['description']}")
        print(f"Humidity: {day['main']['humidity']}%")
        print(f"Pressure: {day['main']['pressure']} hPa")
        print(f"Wind Speed: {day['wind']['speed']} m/s")
        print(f"Wind Direction: {day['wind']['deg']}°")
        print(f"Cloudiness: {day['clouds']['all']}%")
        print(f"Visibility: {day['visibility'] / 1000} km")
        print(f"Sunrise: {sunrise}")
        print("=" * 30)  # Add a separator for clarity


def main():
    global start_date, end_date
    start_date = input("Enter start date (YYYY-MM-DD): ")
    end_date = input("Enter end date (YYYY-MM-DD): ")
    city = input("Enter city name: ")

    while True:
        weather_data = get_weather(city, start_date, end_date)

        if weather_data:
            print_weather_data(weather_data)
        else:
            print("Weather data not available.")

        print("=" * 30)  # Add a separator for clarity

        # Check if user wants to terminate
        terminate = input("Do you want to terminate? (yes/no): ")
        if terminate.lower() == "yes":
            print("=" * 30)  # Add a separator for clarity
            print("Terminating the session...")
            break
        print("=" * 30)  # Add a separator for clarity


        time.sleep(UPDATE_INTERVAL)

if __name__ == "__main__":
    main()
# Out:
# Enter start date (YYYY-MM-DD): 2023-9-1
# Enter end date (YYYY-MM-DD): 2023-9-2
# Enter city name: cairo
# API Request URL: https://api.openweathermap.org/data/2.5/forecast?q=cairo&appid=9ab9a8c1afe3b58d25474f99f0de76d2&units=metric&start_date=2023-9-1&end_date=2023-9-2
# API Request Headers: {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# API Response Content: b'{"cod":"200","message":0,"cnt":40,"list":[{"dt":1693612800,"main":{"temp":26.42,"feels_like":26.42,"temp_min":24.81,"temp_max":26.42,"pressure":1014,"sea_level":1014,"grnd_level":1010,"humidity":69,"temp_kf":1.61},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"clouds":{"all":0},"wind":{"speed":4.78,"deg":13,"gust":6.72},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2023-09-02 00:00:00"},{"dt":1693623600,"main":{"temp":25.63,"feels_like":26.08,"temp_min":24.06,"temp_max":25.63,"pressure":1014,"sea_level":1014,"grnd_level":1010,"humidity":70,"temp_kf":1.57},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"clouds":{"all":0},"wind":{"speed":4.44,"deg":9,"gust":6.6},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2023-09-02 03:00:00"},{"dt":1693634400,"main":{"temp":26.38,"feels_like":26.38,"temp_min":26.36,"temp_max":26.38,"pressure":1013,"sea_level":1013,"grnd_level":1010,"humidity":64,"temp_kf":0.02},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"clouds":{"all":0},"wind":{"speed":4.82,"deg":16,"gust":6.79},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2023-09-02 06:00:00"},{"dt":1693645200,"main":{"temp":33.12,"feels_like":32.45,"temp_min":33.12,"temp_max":33.12,"pressure":1012,"sea_level":1012,"grnd_level":1009,"humidity":32,"temp_kf":0},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"clouds":{"all":0},"wind":{"speed":5.41,"deg":11,"gust":6.89},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2023-09-02 09:00:00"},{"dt":1693656000,"main":{"temp":37.7,"feels_like":36.49,"temp_min":37.7,"temp_max":37.7,"pressure":1010,"sea_level":1010,"grnd_level":1007,"humidity":21,"temp_kf":0},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"clouds":{"all":0},"wind":{"speed":5.57,"deg":357,"gust":6.43},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2023-09-02 12:00:00"},{"dt":1693666800,"main":{"temp":36.63,"feels_like":35.7,"temp_min":36.63,"temp_max":36.63,"pressure":1009,"sea_level":1009,"grnd_level":1007,"humidity":24,"temp_kf":0},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"clouds":{"all":0},"wind":{"speed":8.46,"deg":354,"gust":7.29},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2023-09-02 15:00:00"},{"dt":1693677600,"main":{"temp":30.23,"feels_like":30.21,"temp_min":30.23,"temp_max":30.23,"pressure":1012,"sea_level":1012,"grnd_level":1009,"humidity":42,"temp_kf":0},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"clouds":{"all":0},"wind":{"speed":7.82,"deg":356,"gust":9.49},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2023-09-02 18:00:00"},{"dt":1693688400,"main":{"temp":27.03,"feels_like":28.05,"temp_min":27.03,"temp_max":27.03,"pressure":1012,"sea_level":1012,"grnd_level":1009,"humidity":59,"temp_kf":0},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"clouds":{"all":0},"wind":{"speed":4.87,"deg":358,"gust":6.19},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2023-09-02 21:00:00"},{"dt":1693699200,"main":{"temp":25.19,"feels_like":25.62,"temp_min":25.19,"temp_max":25.19,"pressure":1011,"sea_level":1011,"grnd_level":1009,"humidity":71,"temp_kf":0},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"clouds":{"all":0},"wind":{"speed":4.37,"deg":351,"gust":5.96},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2023-09-03 00:00:00"},{"dt":1693710000,"main":{"temp":24.24,"feels_like":24.65,"temp_min":24.24,"temp_max":24.24,"pressure":1011,"sea_level":1011,"grnd_level":1008,"humidity":74,"temp_kf":0},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"clouds":{"all":0},"wind":{"speed":3.44,"deg":356,"gust":4.54},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2023-09-03 03:00:00"},{"dt":1693720800,"main":{"temp":25.94,"feels_like":26.26,"temp_min":25.94," ...
#
# Weather in Cairo from 2023-9-1 to 2023-9-2:
# Date: 1693612800
# Temperature: None°
# Description: clear sky
# Humidity: 69%
# Pressure: 1014 hPa
# Wind Speed: 4.78 m/s
# Wind Direction: 13°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693623600
# Temperature: None°
# Description: clear sky
# Humidity: 70%
# Pressure: 1014 hPa
# Wind Speed: 4.44 m/s
# Wind Direction: 9°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693634400
# Temperature: None°
# Description: clear sky
# Humidity: 64%
# Pressure: 1013 hPa
# Wind Speed: 4.82 m/s
# Wind Direction: 16°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693645200
# Temperature: None°
# Description: clear sky
# Humidity: 32%
# Pressure: 1012 hPa
# Wind Speed: 5.41 m/s
# Wind Direction: 11°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693656000
# Temperature: None°
# Description: clear sky
# Humidity: 21%
# Pressure: 1010 hPa
# Wind Speed: 5.57 m/s
# Wind Direction: 357°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693666800
# Temperature: None°
# Description: clear sky
# Humidity: 24%
# Pressure: 1009 hPa
# Wind Speed: 8.46 m/s
# Wind Direction: 354°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693677600
# Temperature: None°
# Description: clear sky
# Humidity: 42%
# Pressure: 1012 hPa
# Wind Speed: 7.82 m/s
# Wind Direction: 356°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693688400
# Temperature: None°
# Description: clear sky
# Humidity: 59%
# Pressure: 1012 hPa
# Wind Speed: 4.87 m/s
# Wind Direction: 358°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693699200
# Temperature: None°
# Description: clear sky
# Humidity: 71%
# Pressure: 1011 hPa
# Wind Speed: 4.37 m/s
# Wind Direction: 351°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693710000
# Temperature: None°
# Description: clear sky
# Humidity: 74%
# Pressure: 1011 hPa
# Wind Speed: 3.44 m/s
# Wind Direction: 356°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693720800
# Temperature: None°
# Description: clear sky
# Humidity: 64%
# Pressure: 1011 hPa
# Wind Speed: 3.33 m/s
# Wind Direction: 13°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693731600
# Temperature: None°
# Description: clear sky
# Humidity: 35%
# Pressure: 1010 hPa
# Wind Speed: 2.61 m/s
# Wind Direction: 3°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693742400
# Temperature: None°
# Description: clear sky
# Humidity: 21%
# Pressure: 1008 hPa
# Wind Speed: 2.48 m/s
# Wind Direction: 318°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693753200
# Temperature: None°
# Description: clear sky
# Humidity: 20%
# Pressure: 1006 hPa
# Wind Speed: 4.94 m/s
# Wind Direction: 322°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693764000
# Temperature: None°
# Description: clear sky
# Humidity: 42%
# Pressure: 1009 hPa
# Wind Speed: 6.86 m/s
# Wind Direction: 8°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693774800
# Temperature: None°
# Description: clear sky
# Humidity: 58%
# Pressure: 1010 hPa
# Wind Speed: 4.6 m/s
# Wind Direction: 8°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693785600
# Temperature: None°
# Description: clear sky
# Humidity: 68%
# Pressure: 1008 hPa
# Wind Speed: 3.43 m/s
# Wind Direction: 357°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693796400
# Temperature: None°
# Description: clear sky
# Humidity: 75%
# Pressure: 1008 hPa
# Wind Speed: 3.28 m/s
# Wind Direction: 350°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693807200
# Temperature: None°
# Description: clear sky
# Humidity: 66%
# Pressure: 1008 hPa
# Wind Speed: 2.77 m/s
# Wind Direction: 5°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693818000
# Temperature: None°
# Description: clear sky
# Humidity: 40%
# Pressure: 1007 hPa
# Wind Speed: 2.27 m/s
# Wind Direction: 331°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693828800
# Temperature: None°
# Description: clear sky
# Humidity: 25%
# Pressure: 1005 hPa
# Wind Speed: 2.24 m/s
# Wind Direction: 290°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693839600
# Temperature: None°
# Description: clear sky
# Humidity: 21%
# Pressure: 1004 hPa
# Wind Speed: 3.14 m/s
# Wind Direction: 282°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693850400
# Temperature: None°
# Description: clear sky
# Humidity: 47%
# Pressure: 1006 hPa
# Wind Speed: 6.84 m/s
# Wind Direction: 24°
# Cloudiness: 1%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693861200
# Temperature: None°
# Description: clear sky
# Humidity: 59%
# Pressure: 1007 hPa
# Wind Speed: 4.7 m/s
# Wind Direction: 55°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693872000
# Temperature: None°
# Description: clear sky
# Humidity: 63%
# Pressure: 1006 hPa
# Wind Speed: 3.87 m/s
# Wind Direction: 52°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693882800
# Temperature: None°
# Description: clear sky
# Humidity: 63%
# Pressure: 1006 hPa
# Wind Speed: 3.29 m/s
# Wind Direction: 75°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693893600
# Temperature: None°
# Description: clear sky
# Humidity: 46%
# Pressure: 1007 hPa
# Wind Speed: 1.03 m/s
# Wind Direction: 115°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693904400
# Temperature: None°
# Description: clear sky
# Humidity: 23%
# Pressure: 1007 hPa
# Wind Speed: 3.46 m/s
# Wind Direction: 193°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693915200
# Temperature: None°
# Description: clear sky
# Humidity: 15%
# Pressure: 1006 hPa
# Wind Speed: 4.51 m/s
# Wind Direction: 229°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693926000
# Temperature: None°
# Description: clear sky
# Humidity: 16%
# Pressure: 1006 hPa
# Wind Speed: 3.84 m/s
# Wind Direction: 233°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693936800
# Temperature: None°
# Description: clear sky
# Humidity: 18%
# Pressure: 1007 hPa
# Wind Speed: 3.15 m/s
# Wind Direction: 241°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693947600
# Temperature: None°
# Description: clear sky
# Humidity: 32%
# Pressure: 1009 hPa
# Wind Speed: 1.63 m/s
# Wind Direction: 10°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693958400
# Temperature: None°
# Description: clear sky
# Humidity: 30%
# Pressure: 1008 hPa
# Wind Speed: 1.47 m/s
# Wind Direction: 28°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693969200
# Temperature: None°
# Description: clear sky
# Humidity: 29%
# Pressure: 1008 hPa
# Wind Speed: 1.53 m/s
# Wind Direction: 9°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693980000
# Temperature: None°
# Description: clear sky
# Humidity: 21%
# Pressure: 1009 hPa
# Wind Speed: 1.64 m/s
# Wind Direction: 16°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1693990800
# Temperature: None°
# Description: clear sky
# Humidity: 14%
# Pressure: 1008 hPa
# Wind Speed: 0.94 m/s
# Wind Direction: 41°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1694001600
# Temperature: None°
# Description: clear sky
# Humidity: 10%
# Pressure: 1007 hPa
# Wind Speed: 2.7 m/s
# Wind Direction: 210°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1694012400
# Temperature: None°
# Description: clear sky
# Humidity: 9%
# Pressure: 1006 hPa
# Wind Speed: 4.76 m/s
# Wind Direction: 261°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1694023200
# Temperature: None°
# Description: clear sky
# Humidity: 26%
# Pressure: 1008 hPa
# Wind Speed: 7.81 m/s
# Wind Direction: 54°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# Date: 1694034000
# Temperature: None°
# Description: clear sky
# Humidity: 38%
# Pressure: 1009 hPa
# Wind Speed: 4.84 m/s
# Wind Direction: 35°
# Cloudiness: 2%
# Visibility: 10.0 km
# Sunrise: None
# ==============================
# ==============================
# Do you want to terminate? (yes/no): yes
# ==============================
# Terminating the session...

# %%
# Weather Data for Agriculture Program

import requests
import datetime
import time

API_KEY = '9ab9a8c1afe3b58d25474f99f0de76d2'

def get_weather(city, crop_name, units='metric'):
    base_url = f'https://api.openweathermap.org/data/2.5/weather'
    params = {'q': city, 'appid': API_KEY, 'units': units}
    response = requests.get(base_url, params=params)
    data = response.json()

    if response.status_code == 200:
        return data
    else:
        print(f"API response content: {response.content}")
        return None

def print_weather_data(data, crop_name):
    print("  ")
    print(f"Weather in {data['name']}, {data['sys']['country']}:")
    print(f"Temperature: {data['main']['temp']}°")
    print(f"Description: {data['weather'][0]['description']}")
    print(f"Humidity: {data['main']['humidity']}%")
    print(f"Pressure: {data['main']['pressure']} hPa")
    print(f"Wind Speed: {data['wind']['speed']} m/s")
    print(f"Wind Direction: {data['wind']['deg']}°")
    print(f"Cloudiness: {data['clouds']['all']}%")
    print(f"Visibility: {data['visibility'] / 1000} km")
    print(f"Sunrise: {datetime.datetime.utcfromtimestamp(data['sys']['sunrise']).strftime('%H:%M:%S')} UTC")
    print(f"Sunset: {datetime.datetime.utcfromtimestamp(data['sys']['sunset']).strftime('%H:%M:%S')} UTC")

    print(" ")
    print(f"Ideal weather conditions for {crop_name}:")
    ideal_weather_conditions = {
        "temperature": 25,
        "humidity": 60,
        "sunlight": 8
    }
    print(f"Temperature: {ideal_weather_conditions['temperature']}°")
    print(f"Humidity: {ideal_weather_conditions['humidity']}%")
    print(f"Sunlight hours: {ideal_weather_conditions['sunlight']} hours")

def main():
    city = input("Enter city name: ")
    crop_name = input("Enter crop name: ")
    units = input("Enter units (metric/imperial): ")

    while True:
        weather_data = get_weather(city, crop_name, units)

        if weather_data:
            print_weather_data(weather_data, crop_name)
        else:
            print("Weather data not available.")

        print("=" * 30)  # Add a separator for clarity

        # Check if user wants to terminate
        terminate = input("Do you want to terminate? (yes/no): ")
        if terminate.lower() == "yes":
            print("=" * 30)  # Add a separator for clarity
            print("Terminating the session...")
            break
        print("=" * 30)  # Add a separator for clarity

        time.sleep(UPDATE_INTERVAL)

if __name__ == "__main__":
    main()
# Out:
# Enter city name: cairo
# Enter crop name: corn
# Enter units (metric/imperial): metric
#
# Weather in Cairo, EG:
# Temperature: 26.42°
# Description: clear sky
# Humidity: 69%
# Pressure: 1014 hPa
# Wind Speed: 4.63 m/s
# Wind Direction: 30°
# Cloudiness: 0%
# Visibility: 10.0 km
# Sunrise: 03:32:23 UTC
# Sunset: 16:17:47 UTC
#
# Ideal weather conditions for corn:
# Temperature: 25°
# Humidity: 60%
# Sunlight hours: 8 hours
# ==============================
# Do you want to terminate? (yes/no): yes
# ==============================
# Terminating the session...

# %%
# Traveling Transportation Recommendation Program


import requests
import time
import datetime

def get_weather(city):
    api_key = '9ab9a8c1afe3b58d25474f99f0de76d2'
    base_url = "http://api.openweathermap.org/data/2.5/weather"
    params = {"q": city, "appid": api_key, "units": "metric"}

    response = requests.get(base_url, params=params)
    weather_data = response.json()

    # Extract relevant weather information
    temperature = weather_data["main"]["temp"]
    weather_description = weather_data["weather"][0]["description"]

    return temperature, weather_description

def suggest_travel(city_from, city_to, date):
    temperature_from, weather_from = get_weather(city_from)
    temperature_to, weather_to = get_weather(city_to)

    print(f"Weather in {city_from} on {date}: {weather_from}, {temperature_from}°C")
    print(f"Weather in {city_to} on {date}: {weather_to}, {temperature_to}°C")
    print("=" * 30)  # Add a separator for clarity

    if "rain" in weather_from.lower() or "rain" in weather_to.lower():
        print("It might be best to consider traveling by car or train to stay dry.")
    elif temperature_from > 30 or temperature_to > 30:
        print("Traveling by air-conditioned transportation like a plane could be more comfortable.")
    else:
        print("You can consider any mode of transportation based on your preference!")

# Sample usage
city_from = input("Enter the city you're traveling from: ")
city_to = input("Enter the city you're traveling to: ")
date = input("Enter traveling date (YYYY-MM-DD): ")

suggest_travel(city_from, city_to, date)

while True:
        print("=" * 30)  # Add a separator for clarity
        # Check if user wants to terminate
        terminate = input("Do you want to terminate? (yes/no): ")
        if terminate.lower() == "yes":
            print("=" * 30)  # Add a separator for clarity
            print("Terminating the session...")
            break
        print("=" * 30)  # Add a separator for clarity

        time.sleep(UPDATE_INTERVAL)
# Out:
# Enter the city you're traveling from: cairo
# Enter the city you're traveling to: berlin
# Enter traveling date (YYYY-MM-DD): 2023-9-2
# Weather in cairo on 2023-9-2: clear sky, 26.42°C
# Weather in berlin on 2023-9-2: clear sky, 13.06°C
# ==============================
# You can consider any mode of transportation based on your preference!
# ==============================
# Do you want to terminate? (yes/no): yes
# ==============================
# Terminating the session...
